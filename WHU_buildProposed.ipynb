# %%
#Drive daki dosyalara erişmek için izin verir.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#ilgili calisma klasorune gecer.
import os
os.chdir("/content/drive/MyDrive/WHU")

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# !nvidia-smi
# Out:
# Wed Dec 27 06:09:06 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from numpy.random import seed
seed(1)
from tensorflow.random import set_seed
set_seed(2)

# %%
import os
import cv2
import shutil
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.utils import normalize
import glob
import cv2
from matplotlib import pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import ReLU,Input,AveragePooling2D, Activation, GlobalAveragePooling2D, Conv2D
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, MaxPool2D
from tensorflow.keras.layers import Lambda,GlobalMaxPooling2D, DepthwiseConv2D, Reshape, Permute, Add, concatenate, Concatenate, Multiply


from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras import backend as K
import time

# %%
import os
import cv2
from tqdm import tqdm
from glob import glob
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
import albumentations as A

# %%
print(tf.executing_eagerly())
# Out:
# True

# %%
tr = np.load('/content/drive/MyDrive/WHU/WHU_build_area_train_set_80_percent.npz', allow_pickle=True)
vl = np.load('/content/drive/MyDrive/WHU/WHU_build_area_val_set_10_percent.npz', allow_pickle=True)
ts = np.load('/content/drive/MyDrive/WHU/WHU_build_area_test_set_10_percent.npz', allow_pickle=True)

# %%
print(tr.files)
print(vl.files)
print(ts.files)
# Out:
# ['tr_img', 'tr_msk']
# ['vl_img', 'vl_msk']
# ['ts_img', 'ts_msk']

# %%
#isimlere göre np.array cagrilir.
tr_img = tr['tr_img']
tr_lbl = tr['tr_msk']

vl_img = vl['vl_img']
vl_lbl = vl['vl_msk']

ts_img = ts['ts_img']
ts_lbl = ts['ts_msk']

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.grid(False)
plt.imshow((tr_img[42]))
plt.subplot(1, 2, 2)
plt.grid(False)
plt.imshow(tr_lbl[42])

# %%
np.unique(tr_lbl) #label 255 -> 1 yapilmalidir.
# Out:
# array([  0, 255], dtype=uint8)

# %%
#bu fonk. farklı etikete sahip maskeleri 0,1,2 ... olarak etiketler.
def mask_to_label_encoder(_mask):
  new_mask = np.zeros(_mask.shape,dtype=np.uint8)
  lbl_id = np.unique(_mask)
  print("new id \t: old id\n----------------")
  for i, id in enumerate(lbl_id):
    print(i, " \t: ",id)
    new_mask[np.where(_mask == id)] = i
  return new_mask

# %%
tr_lbl = mask_to_label_encoder(tr_lbl)
vl_lbl = mask_to_label_encoder(vl_lbl)
ts_lbl = mask_to_label_encoder(ts_lbl)
# Out:
# new id 	: old id
# ----------------
# 0  	:  0
# 1  	:  255
# new id 	: old id
# ----------------
# 0  	:  0
# 1  	:  255
# new id 	: old id
# ----------------
# 0  	:  0
# 1  	:  255

# %%
tr_image = np.array(tr_img , dtype='float32')
tr_mask = np.array(tr_lbl , dtype= 'float32')

ts_image = np.array(ts_img , dtype='float32')
ts_mask = np.array(ts_lbl , dtype= 'float32')

vl_image = np.array(vl_img , dtype='float32')
vl_mask = np.array(vl_lbl , dtype= 'float32')

print(tr_image.shape, tr_mask.shape)
print(ts_image.shape, ts_mask.shape)
print(vl_image.shape, vl_mask.shape)
# Out:
# (2399, 256, 256, 3) (2399, 256, 256)
# (300, 256, 256, 3) (300, 256, 256)
# (300, 256, 256, 3) (300, 256, 256)

# %%
def augment_data(images, masks):
  H = W = 256
  new_image = []
  new_mask = []
  imag = []
  mask = []

  aug = A.Compose([
      A.RandomSizedCrop((256-80, 256-10), H, W),
      A.ShiftScaleRotate(),
      A.RGBShift(),
      A.Blur(),
      A.GaussNoise(),
      A.ChannelShuffle(p=1)
      ],p=1)

  for img, msk in tqdm(zip(images, masks), total=len(images)):
    augmented = aug(image=img, mask=msk)
    imag.append(augmented["image"])
    mask.append(augmented["mask"])
    imag.append(img)
    mask.append(msk)

  for i,m in tqdm(zip(imag, mask), total=len(imag)):
      new_image.append(cv2.resize(i, (W, H)))
      new_mask.append(cv2.resize(m, (W, H)))
  return np.array(new_image), np.array(new_mask)

# %%
"""tr_image, tr_mask = augment_data(tr_image, tr_mask)
vl_image, vl_mask = augment_data(vl_image, vl_mask)"""
# Out:
# 'tr_image, tr_mask = augment_data(tr_image, tr_mask)\nvl_image, vl_mask = augment_data(vl_image, vl_mask)'

# %%
print(tr_image.shape, tr_mask.shape)
print(vl_image.shape, vl_mask.shape)
# Out:
# (2399, 256, 256, 3) (2399, 256, 256)
# (300, 256, 256, 3) (300, 256, 256)

# %%
image_num = 23
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.grid(False)
plt.imshow((tr_image[image_num])/255)
plt.subplot(1, 2, 2)
plt.grid(False)
plt.imshow(tr_mask[image_num])

# %%
tr_mask = np.expand_dims(tr_mask, axis = 3)
ts_mask = np.expand_dims(ts_mask, axis = 3)
vl_mask = np.expand_dims(vl_mask, axis = 3)

# %%
print(tr_image.shape, tr_mask.shape)
print(ts_image.shape, ts_mask.shape)
print(vl_image.shape, vl_mask.shape)
# Out:
# (2399, 256, 256, 3) (2399, 256, 256, 1)
# (300, 256, 256, 3) (300, 256, 256, 1)
# (300, 256, 256, 3) (300, 256, 256, 1)

# %% [markdown]
# normalization

# %%
tr_image= tr_image / 255.0
ts_image = ts_image / 255.0
vl_image = vl_image / 255.0

# %%
#losses
def tversky(y_true, y_pred, smooth=1, alpha=0.7):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = K.sum((1 - y_true_pos) * y_pred_pos)
    return (true_pos + smooth) / (true_pos + alpha * false_neg + (1 - alpha) * false_pos + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return K.pow((1 - tv), gamma)

def jaccard_coef(y_true, y_pred):
    y_true = tf.cast(y_true, y_pred.dtype)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    """y_true_f = tf.cast(y_true_f, tf.float32)
    y_pred_f = tf.cast(y_pred_f, tf.float32)"""
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jaccard_coef_loss(y_true, y_pred):
    return 1.0 - jaccard_coef(y_true, y_pred)

def dice_coef(y_true, y_pred):
    #y_true = tf.cast(y_true, y_pred.dtype)
    smooth = 1
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):

    return 1.0 - dice_coef(y_true, y_pred)

# %%
EPOCH = 100

# %%
#asymmetric convolution
def convolution_block_2(block_input, n_filters=128, kernel_size=3, stride=1, dilation_rate=1,padding="same",use_bias=False, _name=''):
  ks1, ks2, ks3, ks4 = kernel_size, 1, 1, kernel_size
  x = Conv2D(
      n_filters,
      kernel_size=(ks1, ks2),
      strides=stride,
      dilation_rate=dilation_rate,
      padding="same",
      use_bias=use_bias,
      kernel_initializer=keras.initializers.HeNormal(),
      name=str(_name)+'_Conv1'
  )(block_input)
  x = Conv2D(
      n_filters,
      kernel_size=(ks3, ks4),
      strides=stride,
      dilation_rate=dilation_rate,
      padding="same",
      use_bias=use_bias,
      kernel_initializer=keras.initializers.HeNormal(),
      name=str(_name)+'_Conv2'
  )(x)
  x = BatchNormalization(name=str(_name)+'_batchNorm1')(x)
  return tf.nn.relu(x,name=str(_name)+'_relu1')

# %%
def DilatedSpatialPyramidPooling(dspp_input, n_filters):

    dims = dspp_input.shape

    out_1 = tf.keras.layers.Conv2D(filters=n_filters,kernel_size=(1,1), kernel_initializer='he_normal', padding='same', name='GDASPP_Conv_Block1')(dspp_input)
    out_6 = convolution_block_2(dspp_input,n_filters, kernel_size=3, dilation_rate=6, _name='GDASPP_Conv_Block2')
    out_12 = convolution_block_2(dspp_input,n_filters, kernel_size=3, dilation_rate=12, _name='GDASPP_Conv_Block3')
    out_18 = convolution_block_2(dspp_input,n_filters, kernel_size=3, dilation_rate=18, _name='GDASPP_Conv_Block4')

    con_1 = tf.keras.layers.Concatenate(axis=3)([out_1,out_6,out_12,out_18])

    #---------------------------------------------------#
    #----------------------SAM--------------------------#
    #---------------------------------------------------#

    sig_1   = tf.keras.layers.Conv2D(filters=1,kernel_size=(5,5), activation='sigmoid', kernel_initializer='he_normal', padding='same', use_bias=False)(out_1)
    sig_6   = tf.keras.layers.Conv2D(filters=1,kernel_size=(5,5), activation='sigmoid', kernel_initializer='he_normal', padding='same', use_bias=False)(out_6)
    sig_12 = tf.keras.layers.Conv2D(filters=1,kernel_size=(5,5), activation='sigmoid', kernel_initializer='he_normal', padding='same', use_bias=False)(out_12)
    sig_18 = tf.keras.layers.Conv2D(filters=1,kernel_size=(5,5), activation='sigmoid', kernel_initializer='he_normal', padding='same', use_bias=False)(out_18)

    mul_1   = tf.keras.layers.Multiply()([out_1, sig_1])
    mul_6   = tf.keras.layers.Multiply()([out_6, sig_6])
    mul_12  = tf.keras.layers.Multiply()([out_12, sig_12])
    mul_18  = tf.keras.layers.Multiply()([out_18, sig_18])

    con_2 = tf.keras.layers.Concatenate(axis=3)([mul_1,mul_6,mul_12,mul_18])
    #---------------------------------------------------#
    #----------------------CAM--------------------------#
    #---------------------------------------------------#
    x = tf.keras.layers.GlobalAveragePooling2D()(con_2)
    x = tf.keras.layers.Dense(units=n_filters*4)(x)
    x = tf.keras.layers.Dense(units=n_filters*4)(x)
    x = tf.keras.layers.Activation('sigmoid')(x)

    cam_reshape = tf.keras.layers.Reshape(( 1, 1, n_filters*4))(x)
    mul_2 = tf.keras.layers.Multiply()([con_2, cam_reshape])
    add_2 = tf.keras.layers.Add()([con_1, mul_2])
    #---------------------------------------------------#

    con_4 = convolution_block_2(add_2, kernel_size=1, _name='GDASPP_Conv_Block5')

    return con_4

# %%
#standard convolution
def conv2d(block_input, num_filters=128, kernel_size=3, stride=1, dilation_rate=1,padding="same", groups=1, use_bias=False):
  x = Conv2D(
      num_filters,
      kernel_size=kernel_size,
      strides = stride,
      groups=groups,
      dilation_rate=dilation_rate,
      padding="same",
      use_bias=use_bias,
      kernel_initializer=keras.initializers.HeNormal()
  )(block_input)
  return x

# %%
#depthwise Convolution
def DWConv2d(block_input, kernel_size=3, strides = (1,1), dilation_rate=1, padding="same", depth_multiplier=1, use_bias=True):
  x = DepthwiseConv2D(
      kernel_size =  kernel_size,
      strides = strides,
      padding = padding,
      depth_multiplier=depth_multiplier,
      data_format=None,
      dilation_rate=dilation_rate,
      activation=None,
      use_bias=use_bias,
      depthwise_initializer='glorot_uniform'
  )(block_input)
  return x

# %%
#Encoder-Decoder Residual Block
def EDRB(_x, groups, dilated_rate, n_filters): #efficient Residual Bottleneck Module
  #NOT:3x1 ve 1x3 conv islemleri art arda yapilirsa 3x3 conv islemine denk gelir
  #ancak islem sayisi direkt 3x3 conv a göre azaltilir. Bu islem soerable convolution olarak gecer.
  #-------------------------------------------------------------------------------------#
  #-----------------------------Fist Block----------------------------------------------#

  #1x1 Kernel Conv
  x_1 = conv2d(_x, num_filters=n_filters//2, kernel_size=(1,1), dilation_rate=1, padding="same",use_bias=True)
  #batch norm. and relu
  x_1 = BatchNormalization()(x_1)
  x_1 = tf.nn.relu(x_1)

  #3x1 DWConv
  x_dw = DWConv2d(x_1, kernel_size=(3,1), strides = (1,1), dilation_rate=1, padding="same", depth_multiplier=1, use_bias=True)
  #1x3 DWConv
  x_dw = DWConv2d(x_dw, kernel_size=(1,3), strides = (1,1), dilation_rate=1, padding="same", depth_multiplier=1, use_bias=True)
  #batch norm. and relu
  x_dw = BatchNormalization()(x_dw)
  x_dw = tf.nn.relu(x_dw)

  #3x1 Kernel Conv
  x_co = conv2d(x_1, num_filters=n_filters//2, kernel_size=(3,1), dilation_rate = dilated_rate, padding="same",use_bias=True)
  #1x3 Kernel Conv
  x_co = conv2d(x_co, num_filters=n_filters//2, kernel_size=(1,3), dilation_rate = dilated_rate, padding="same",use_bias=True)
  #batch norm. and relu
  x_co = BatchNormalization()(x_co)
  x_co = tf.nn.relu(x_co)

  #Concatenate
  x_cnc = concatenate([x_dw, x_co], axis=3)

  #1x1 conv
  x_2 = conv2d(x_cnc, num_filters=n_filters//2, kernel_size=(1,1), dilation_rate=1, padding="same",use_bias=True)
  #batch norm. and relu
  x_2 = BatchNormalization()(x_2)
  x_2 = tf.nn.relu(x_2)

  #Add
  x_add = Add()([x_1, x_2])

  #-------------------------------------------------------------------------------------#
  #-----------------------------Second Block--------------------------------------------#

  #1x1 Kernel Conv
  x2_1 = conv2d(x_add, num_filters=n_filters//2, kernel_size=(1,1), dilation_rate=1, padding="same",use_bias=True)
  #batch norm. and relu
  x2_1 = BatchNormalization()(x2_1)
  x2_1 = tf.nn.relu(x2_1)

  #3x1 DWConv
  x2_dw = DWConv2d(x2_1, kernel_size=(3,1), strides = (1,1), dilation_rate=1, padding="same", depth_multiplier=1, use_bias=True)
  #1x3 DWConv
  x2_dw = DWConv2d(x2_dw, kernel_size=(1,3), strides = (1,1), dilation_rate=1, padding="same", depth_multiplier=1, use_bias=True)
  #batch norm. and relu
  x2_dw = BatchNormalization()(x2_dw)
  x2_dw = tf.nn.relu(x2_dw)

  #3x1 Kernel Conv
  x2_co = conv2d(x2_1, num_filters=n_filters//2, kernel_size=(3,1), dilation_rate = dilated_rate, padding="same",use_bias=True)
  #1x3 Kernel Conv
  x2_co = conv2d(x2_co, num_filters=n_filters//2, kernel_size=(1,3), dilation_rate = dilated_rate, padding="same",use_bias=True)
  #batch norm. and relu
  x2_co = BatchNormalization()(x2_co)
  x2_co = tf.nn.relu(x2_co)

  #Concatenate
  x2_cnc = concatenate([x2_dw, x2_co], axis=3)

  #1x1 conv
  x2_2 = conv2d(x2_cnc, num_filters=n_filters//2, kernel_size=(1,1), dilation_rate=1, padding="same",use_bias=True)
  #batch norm. and relu
  x2_2 = BatchNormalization()(x2_2)
  x2_2 = tf.nn.relu(x2_2)

  #Add
  x2_add = Add()([x_add, x2_2])

  x2_add = Add()([x_1, x2_add])

  return x2_add

# %%
def downsample_block(x, groups, dilated_rate, n_filters):
   f = EDRB(x, groups=groups, dilated_rate=dilated_rate, n_filters=n_filters)
   p = MaxPool2D(2)(f)
   return f, p

# %%
def upsample_block(x, groups, dilated_rate, conv_features, n_filters):
   # upsample
   x = Conv2DTranspose(n_filters, kernel_size=3, strides=2, padding="same", activation='relu')(x)
   # concatenate
   x = concatenate([x, conv_features])
   # Conv2D twice with ReLU activation
   x = EDRB(x, groups=groups, dilated_rate=dilated_rate, n_filters=n_filters)
   return x

# %%
def proposed_model():
  # inputs
  inputs = Input(shape=(256,256,3))
  # encoder: contracting path - downsample
  # 1 - downsample
  f1, p1 = downsample_block(inputs, groups=1, dilated_rate=2, n_filters=24)
  # 2 - downsample
  f2, p2 = downsample_block(p1, groups=1, dilated_rate=4, n_filters=48)
  # 3 - downsample
  f3, p3 = downsample_block(p2, groups=1, dilated_rate=8, n_filters=72)
  # 4 - downsample
  f4, p4 = downsample_block(p3, groups=1, dilated_rate=16, n_filters=96)
  # 5 - bottleneck
  #bottleneck = double_conv_block(p4, 512)
  #yeni blok, downsample blok 2

  bottleneck = DilatedSpatialPyramidPooling(p4, 72)
  # decoder: expanding path - upsample
  # 6 - upsample
  u6 = upsample_block(bottleneck, groups=1, dilated_rate=16, conv_features=f4, n_filters=96)
  # 7 - upsample
  u7 = upsample_block(u6, groups=1, dilated_rate=8, conv_features=f3, n_filters=72)
  # 8 - upsample
  u8 = upsample_block(u7, groups=1, dilated_rate=4, conv_features=f2, n_filters=48)
  # 9 - upsample
  u9 = upsample_block(u8, groups=1, dilated_rate=2, conv_features=f1, n_filters=24)
  # outputs
  outputs = Conv2D(1, 1, padding="same", activation = "sigmoid")(u9)
  # unet model with Keras Functional API
  model = tf.keras.Model(inputs, outputs, name="U-Net")
  return model

# %%
proposed_model = proposed_model()
proposed_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 12)         48        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 12)         48        ['conv2d[0][0]']
#  Normalization)
#
#  tf.nn.relu (TFOpLambda)     (None, 256, 256, 12)         0         ['batch_normalization[0][0]']
#
#  depthwise_conv2d (Depthwis  (None, 256, 256, 12)         48        ['tf.nn.relu[0][0]']
#  eConv2D)
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 12)         444       ['tf.nn.relu[0][0]']
#
#  depthwise_conv2d_1 (Depthw  (None, 256, 256, 12)         48        ['depthwise_conv2d[0][0]']
#  iseConv2D)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 12)         444       ['conv2d_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 12)         48        ['depthwise_conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 256, 256, 12)         48        ['conv2d_2[0][0]']
#  chNormalization)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 256, 256, 12)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 256, 256, 12)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 256, 256, 24)         0         ['tf.nn.relu_1[0][0]',
#                                                                      'tf.nn.relu_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 12)         300       ['concatenate[0][0]']
#
#  batch_normalization_3 (Bat  (None, 256, 256, 12)         48        ['conv2d_3[0][0]']
#  chNormalization)
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 256, 256, 12)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 256, 256, 12)         0         ['tf.nn.relu[0][0]',
#                                                                      'tf.nn.relu_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 12)         156       ['add[0][0]']
#
#  batch_normalization_4 (Bat  (None, 256, 256, 12)         48        ['conv2d_4[0][0]']
#  chNormalization)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 256, 256, 12)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  depthwise_conv2d_2 (Depthw  (None, 256, 256, 12)         48        ['tf.nn.relu_4[0][0]']
#  iseConv2D)
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 12)         444       ['tf.nn.relu_4[0][0]']
#
#  depthwise_conv2d_3 (Depthw  (None, 256, 256, 12)         48        ['depthwise_conv2d_2[0][0]']
#  iseConv2D)
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 12)         444       ['conv2d_5[0][0]']
#
#  batch_normalization_5 (Bat  (None, 256, 256, 12)         48        ['depthwise_conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 256, 256, 12)         48        ['conv2d_6[0][0]']
#  chNormalization)
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 256, 256, 12)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  tf.nn.relu_6 (TFOpLambda)   (None, 256, 256, 12)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 256, 256, 24)         0         ['tf.nn.relu_5[0][0]',
#  )                                                                   'tf.nn.relu_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 12)         300       ['concatenate_1[0][0]']
#
#  batch_normalization_7 (Bat  (None, 256, 256, 12)         48        ['conv2d_7[0][0]']
#  chNormalization)
#
#  tf.nn.relu_7 (TFOpLambda)   (None, 256, 256, 12)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 256, 256, 12)         0         ['add[0][0]',
#                                                                      'tf.nn.relu_7[0][0]']
#
#  add_2 (Add)                 (None, 256, 256, 12)         0         ['tf.nn.relu[0][0]',
#                                                                      'add_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 12)         0         ['add_2[0][0]']
#  D)
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 24)         312       ['max_pooling2d[0][0]']
#
#  batch_normalization_8 (Bat  (None, 128, 128, 24)         96        ['conv2d_8[0][0]']
#  chNormalization)
#
#  tf.nn.relu_8 (TFOpLambda)   (None, 128, 128, 24)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  depthwise_conv2d_4 (Depthw  (None, 128, 128, 24)         96        ['tf.nn.relu_8[0][0]']
#  iseConv2D)
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 24)         1752      ['tf.nn.relu_8[0][0]']
#
#  depthwise_conv2d_5 (Depthw  (None, 128, 128, 24)         96        ['depthwise_conv2d_4[0][0]']
#  iseConv2D)
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 24)         1752      ['conv2d_9[0][0]']
#
#  batch_normalization_9 (Bat  (None, 128, 128, 24)         96        ['depthwise_conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 128, 128, 24)         96        ['conv2d_10[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_9 (TFOpLambda)   (None, 128, 128, 24)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  tf.nn.relu_10 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  concatenate_2 (Concatenate  (None, 128, 128, 48)         0         ['tf.nn.relu_9[0][0]',
#  )                                                                   'tf.nn.relu_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 24)         1176      ['concatenate_2[0][0]']
#
#  batch_normalization_11 (Ba  (None, 128, 128, 24)         96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_11 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  add_3 (Add)                 (None, 128, 128, 24)         0         ['tf.nn.relu_8[0][0]',
#                                                                      'tf.nn.relu_11[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 24)         600       ['add_3[0][0]']
#
#  batch_normalization_12 (Ba  (None, 128, 128, 24)         96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_12 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  depthwise_conv2d_6 (Depthw  (None, 128, 128, 24)         96        ['tf.nn.relu_12[0][0]']
#  iseConv2D)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 24)         1752      ['tf.nn.relu_12[0][0]']
#
#  depthwise_conv2d_7 (Depthw  (None, 128, 128, 24)         96        ['depthwise_conv2d_6[0][0]']
#  iseConv2D)
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 24)         1752      ['conv2d_13[0][0]']
#
#  batch_normalization_13 (Ba  (None, 128, 128, 24)         96        ['depthwise_conv2d_7[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 128, 128, 24)         96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_13 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  tf.nn.relu_14 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  concatenate_3 (Concatenate  (None, 128, 128, 48)         0         ['tf.nn.relu_13[0][0]',
#  )                                                                   'tf.nn.relu_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 24)         1176      ['concatenate_3[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128, 128, 24)         96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_15 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 128, 128, 24)         0         ['add_3[0][0]',
#                                                                      'tf.nn.relu_15[0][0]']
#
#  add_5 (Add)                 (None, 128, 128, 24)         0         ['tf.nn.relu_8[0][0]',
#                                                                      'add_4[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 24)           0         ['add_5[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 36)           900       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 36)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_16 (TFOpLambda)  (None, 64, 64, 36)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  depthwise_conv2d_8 (Depthw  (None, 64, 64, 36)           144       ['tf.nn.relu_16[0][0]']
#  iseConv2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 36)           3924      ['tf.nn.relu_16[0][0]']
#
#  depthwise_conv2d_9 (Depthw  (None, 64, 64, 36)           144       ['depthwise_conv2d_8[0][0]']
#  iseConv2D)
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 36)           3924      ['conv2d_17[0][0]']
#
#  batch_normalization_17 (Ba  (None, 64, 64, 36)           144       ['depthwise_conv2d_9[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 64, 64, 36)           144       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_17 (TFOpLambda)  (None, 64, 64, 36)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  tf.nn.relu_18 (TFOpLambda)  (None, 64, 64, 36)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 64, 64, 72)           0         ['tf.nn.relu_17[0][0]',
#  )                                                                   'tf.nn.relu_18[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 36)           2628      ['concatenate_4[0][0]']
#
#  batch_normalization_19 (Ba  (None, 64, 64, 36)           144       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_19 (TFOpLambda)  (None, 64, 64, 36)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 64, 64, 36)           0         ['tf.nn.relu_16[0][0]',
#                                                                      'tf.nn.relu_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 36)           1332      ['add_6[0][0]']
#
#  batch_normalization_20 (Ba  (None, 64, 64, 36)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_20 (TFOpLambda)  (None, 64, 64, 36)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  depthwise_conv2d_10 (Depth  (None, 64, 64, 36)           144       ['tf.nn.relu_20[0][0]']
#  wiseConv2D)
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 36)           3924      ['tf.nn.relu_20[0][0]']
#
#  depthwise_conv2d_11 (Depth  (None, 64, 64, 36)           144       ['depthwise_conv2d_10[0][0]']
#  wiseConv2D)
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 36)           3924      ['conv2d_21[0][0]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 36)           144       ['depthwise_conv2d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 64, 64, 36)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_21 (TFOpLambda)  (None, 64, 64, 36)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  tf.nn.relu_22 (TFOpLambda)  (None, 64, 64, 36)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  concatenate_5 (Concatenate  (None, 64, 64, 72)           0         ['tf.nn.relu_21[0][0]',
#  )                                                                   'tf.nn.relu_22[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 36)           2628      ['concatenate_5[0][0]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 36)           144       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_23 (TFOpLambda)  (None, 64, 64, 36)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  add_7 (Add)                 (None, 64, 64, 36)           0         ['add_6[0][0]',
#                                                                      'tf.nn.relu_23[0][0]']
#
#  add_8 (Add)                 (None, 64, 64, 36)           0         ['tf.nn.relu_16[0][0]',
#                                                                      'add_7[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 36)           0         ['add_8[0][0]']
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 48)           1776      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_24 (Ba  (None, 32, 32, 48)           192       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_24 (TFOpLambda)  (None, 32, 32, 48)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  depthwise_conv2d_12 (Depth  (None, 32, 32, 48)           192       ['tf.nn.relu_24[0][0]']
#  wiseConv2D)
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 48)           6960      ['tf.nn.relu_24[0][0]']
#
#  depthwise_conv2d_13 (Depth  (None, 32, 32, 48)           192       ['depthwise_conv2d_12[0][0]']
#  wiseConv2D)
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 48)           6960      ['conv2d_25[0][0]']
#
#  batch_normalization_25 (Ba  (None, 32, 32, 48)           192       ['depthwise_conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 32, 32, 48)           192       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_25 (TFOpLambda)  (None, 32, 32, 48)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  tf.nn.relu_26 (TFOpLambda)  (None, 32, 32, 48)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, 32, 32, 96)           0         ['tf.nn.relu_25[0][0]',
#  )                                                                   'tf.nn.relu_26[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 48)           4656      ['concatenate_6[0][0]']
#
#  batch_normalization_27 (Ba  (None, 32, 32, 48)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_27 (TFOpLambda)  (None, 32, 32, 48)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  add_9 (Add)                 (None, 32, 32, 48)           0         ['tf.nn.relu_24[0][0]',
#                                                                      'tf.nn.relu_27[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 48)           2352      ['add_9[0][0]']
#
#  batch_normalization_28 (Ba  (None, 32, 32, 48)           192       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_28 (TFOpLambda)  (None, 32, 32, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  depthwise_conv2d_14 (Depth  (None, 32, 32, 48)           192       ['tf.nn.relu_28[0][0]']
#  wiseConv2D)
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 48)           6960      ['tf.nn.relu_28[0][0]']
#
#  depthwise_conv2d_15 (Depth  (None, 32, 32, 48)           192       ['depthwise_conv2d_14[0][0]']
#  wiseConv2D)
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 48)           6960      ['conv2d_29[0][0]']
#
#  batch_normalization_29 (Ba  (None, 32, 32, 48)           192       ['depthwise_conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 32, 32, 48)           192       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_29 (TFOpLambda)  (None, 32, 32, 48)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  tf.nn.relu_30 (TFOpLambda)  (None, 32, 32, 48)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  concatenate_7 (Concatenate  (None, 32, 32, 96)           0         ['tf.nn.relu_29[0][0]',
#  )                                                                   'tf.nn.relu_30[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 48)           4656      ['concatenate_7[0][0]']
#
#  batch_normalization_31 (Ba  (None, 32, 32, 48)           192       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_31 (TFOpLambda)  (None, 32, 32, 48)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 32, 32, 48)           0         ['add_9[0][0]',
#                                                                      'tf.nn.relu_31[0][0]']
#
#  add_11 (Add)                (None, 32, 32, 48)           0         ['tf.nn.relu_24[0][0]',
#                                                                      'add_10[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 48)           0         ['add_11[0][0]']
#  g2D)
#
#  GDASPP_Conv_Block2_Conv1 (  (None, 16, 16, 72)           10368     ['max_pooling2d_3[0][0]']
#  Conv2D)
#
#  GDASPP_Conv_Block3_Conv1 (  (None, 16, 16, 72)           10368     ['max_pooling2d_3[0][0]']
#  Conv2D)
#
#  GDASPP_Conv_Block4_Conv1 (  (None, 16, 16, 72)           10368     ['max_pooling2d_3[0][0]']
#  Conv2D)
#
#  GDASPP_Conv_Block2_Conv2 (  (None, 16, 16, 72)           15552     ['GDASPP_Conv_Block2_Conv1[0][
#  Conv2D)                                                            0]']
#
#  GDASPP_Conv_Block3_Conv2 (  (None, 16, 16, 72)           15552     ['GDASPP_Conv_Block3_Conv1[0][
#  Conv2D)                                                            0]']
#
#  GDASPP_Conv_Block4_Conv2 (  (None, 16, 16, 72)           15552     ['GDASPP_Conv_Block4_Conv1[0][
#  Conv2D)                                                            0]']
#
#  GDASPP_Conv_Block2_batchNo  (None, 16, 16, 72)           288       ['GDASPP_Conv_Block2_Conv2[0][
#  rm1 (BatchNormalization)                                           0]']
#
#  GDASPP_Conv_Block3_batchNo  (None, 16, 16, 72)           288       ['GDASPP_Conv_Block3_Conv2[0][
#  rm1 (BatchNormalization)                                           0]']
#
#  GDASPP_Conv_Block4_batchNo  (None, 16, 16, 72)           288       ['GDASPP_Conv_Block4_Conv2[0][
#  rm1 (BatchNormalization)                                           0]']
#
#  GDASPP_Conv_Block1 (Conv2D  (None, 16, 16, 72)           3528      ['max_pooling2d_3[0][0]']
#  )
#
#  tf.nn.relu_32 (TFOpLambda)  (None, 16, 16, 72)           0         ['GDASPP_Conv_Block2_batchNorm
#                                                                     1[0][0]']
#
#  tf.nn.relu_33 (TFOpLambda)  (None, 16, 16, 72)           0         ['GDASPP_Conv_Block3_batchNorm
#                                                                     1[0][0]']
#
#  tf.nn.relu_34 (TFOpLambda)  (None, 16, 16, 72)           0         ['GDASPP_Conv_Block4_batchNorm
#                                                                     1[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 1)            1800      ['GDASPP_Conv_Block1[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 1)            1800      ['tf.nn.relu_32[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 1)            1800      ['tf.nn.relu_33[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 16, 16, 1)            1800      ['tf.nn.relu_34[0][0]']
#
#  multiply (Multiply)         (None, 16, 16, 72)           0         ['GDASPP_Conv_Block1[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  multiply_1 (Multiply)       (None, 16, 16, 72)           0         ['tf.nn.relu_32[0][0]',
#                                                                      'conv2d_33[0][0]']
#
#  multiply_2 (Multiply)       (None, 16, 16, 72)           0         ['tf.nn.relu_33[0][0]',
#                                                                      'conv2d_34[0][0]']
#
#  multiply_3 (Multiply)       (None, 16, 16, 72)           0         ['tf.nn.relu_34[0][0]',
#                                                                      'conv2d_35[0][0]']
#
#  concatenate_9 (Concatenate  (None, 16, 16, 288)          0         ['multiply[0][0]',
#  )                                                                   'multiply_1[0][0]',
#                                                                      'multiply_2[0][0]',
#                                                                      'multiply_3[0][0]']
#
#  global_average_pooling2d (  (None, 288)                  0         ['concatenate_9[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 288)                  83232     ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 288)                  83232     ['dense[0][0]']
#
#  activation (Activation)     (None, 288)                  0         ['dense_1[0][0]']
#
#  reshape (Reshape)           (None, 1, 1, 288)            0         ['activation[0][0]']
#
#  concatenate_8 (Concatenate  (None, 16, 16, 288)          0         ['GDASPP_Conv_Block1[0][0]',
#  )                                                                   'tf.nn.relu_32[0][0]',
#                                                                      'tf.nn.relu_33[0][0]',
#                                                                      'tf.nn.relu_34[0][0]']
#
#  multiply_4 (Multiply)       (None, 16, 16, 288)          0         ['concatenate_9[0][0]',
#                                                                      'reshape[0][0]']
#
#  add_12 (Add)                (None, 16, 16, 288)          0         ['concatenate_8[0][0]',
#                                                                      'multiply_4[0][0]']
#
#  GDASPP_Conv_Block5_Conv1 (  (None, 16, 16, 128)          36864     ['add_12[0][0]']
#  Conv2D)
#
#  GDASPP_Conv_Block5_Conv2 (  (None, 16, 16, 128)          16384     ['GDASPP_Conv_Block5_Conv1[0][
#  Conv2D)                                                            0]']
#
#  GDASPP_Conv_Block5_batchNo  (None, 16, 16, 128)          512       ['GDASPP_Conv_Block5_Conv2[0][
#  rm1 (BatchNormalization)                                           0]']
#
#  tf.nn.relu_35 (TFOpLambda)  (None, 16, 16, 128)          0         ['GDASPP_Conv_Block5_batchNorm
#                                                                     1[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 96)           110688    ['tf.nn.relu_35[0][0]']
#  anspose)
#
#  concatenate_10 (Concatenat  (None, 32, 32, 144)          0         ['conv2d_transpose[0][0]',
#  e)                                                                  'add_11[0][0]']
# ...
#
#  conv2d_55 (Conv2D)          (None, 128, 128, 24)         1176      ['concatenate_17[0][0]']
#
#  batch_normalization_51 (Ba  (None, 128, 128, 24)         96        ['conv2d_55[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_55 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  add_19 (Add)                (None, 128, 128, 24)         0         ['tf.nn.relu_52[0][0]',
#                                                                      'tf.nn.relu_55[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 128, 128, 24)         600       ['add_19[0][0]']
#
#  batch_normalization_52 (Ba  (None, 128, 128, 24)         96        ['conv2d_56[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_56 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  depthwise_conv2d_26 (Depth  (None, 128, 128, 24)         96        ['tf.nn.relu_56[0][0]']
#  wiseConv2D)
#
#  conv2d_57 (Conv2D)          (None, 128, 128, 24)         1752      ['tf.nn.relu_56[0][0]']
#
#  depthwise_conv2d_27 (Depth  (None, 128, 128, 24)         96        ['depthwise_conv2d_26[0][0]']
#  wiseConv2D)
#
#  conv2d_58 (Conv2D)          (None, 128, 128, 24)         1752      ['conv2d_57[0][0]']
#
#  batch_normalization_53 (Ba  (None, 128, 128, 24)         96        ['depthwise_conv2d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_54 (Ba  (None, 128, 128, 24)         96        ['conv2d_58[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_57 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  tf.nn.relu_58 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  concatenate_18 (Concatenat  (None, 128, 128, 48)         0         ['tf.nn.relu_57[0][0]',
#  e)                                                                  'tf.nn.relu_58[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 128, 128, 24)         1176      ['concatenate_18[0][0]']
#
#  batch_normalization_55 (Ba  (None, 128, 128, 24)         96        ['conv2d_59[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_59 (TFOpLambda)  (None, 128, 128, 24)         0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  add_20 (Add)                (None, 128, 128, 24)         0         ['add_19[0][0]',
#                                                                      'tf.nn.relu_59[0][0]']
#
#  add_21 (Add)                (None, 128, 128, 24)         0         ['tf.nn.relu_52[0][0]',
#                                                                      'add_20[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 24)         5208      ['add_21[0][0]']
#  Transpose)
#
#  concatenate_19 (Concatenat  (None, 256, 256, 36)         0         ['conv2d_transpose_3[0][0]',
#  e)                                                                  'add_2[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 256, 256, 12)         444       ['concatenate_19[0][0]']
#
#  batch_normalization_56 (Ba  (None, 256, 256, 12)         48        ['conv2d_60[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_60 (TFOpLambda)  (None, 256, 256, 12)         0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  depthwise_conv2d_28 (Depth  (None, 256, 256, 12)         48        ['tf.nn.relu_60[0][0]']
#  wiseConv2D)
#
#  conv2d_61 (Conv2D)          (None, 256, 256, 12)         444       ['tf.nn.relu_60[0][0]']
#
#  depthwise_conv2d_29 (Depth  (None, 256, 256, 12)         48        ['depthwise_conv2d_28[0][0]']
#  wiseConv2D)
#
#  conv2d_62 (Conv2D)          (None, 256, 256, 12)         444       ['conv2d_61[0][0]']
#
#  batch_normalization_57 (Ba  (None, 256, 256, 12)         48        ['depthwise_conv2d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_58 (Ba  (None, 256, 256, 12)         48        ['conv2d_62[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_61 (TFOpLambda)  (None, 256, 256, 12)         0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  tf.nn.relu_62 (TFOpLambda)  (None, 256, 256, 12)         0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  concatenate_20 (Concatenat  (None, 256, 256, 24)         0         ['tf.nn.relu_61[0][0]',
#  e)                                                                  'tf.nn.relu_62[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 256, 256, 12)         300       ['concatenate_20[0][0]']
#
#  batch_normalization_59 (Ba  (None, 256, 256, 12)         48        ['conv2d_63[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_63 (TFOpLambda)  (None, 256, 256, 12)         0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  add_22 (Add)                (None, 256, 256, 12)         0         ['tf.nn.relu_60[0][0]',
#                                                                      'tf.nn.relu_63[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 256, 256, 12)         156       ['add_22[0][0]']
#
#  batch_normalization_60 (Ba  (None, 256, 256, 12)         48        ['conv2d_64[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_64 (TFOpLambda)  (None, 256, 256, 12)         0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  depthwise_conv2d_30 (Depth  (None, 256, 256, 12)         48        ['tf.nn.relu_64[0][0]']
#  wiseConv2D)
#
#  conv2d_65 (Conv2D)          (None, 256, 256, 12)         444       ['tf.nn.relu_64[0][0]']
#
#  depthwise_conv2d_31 (Depth  (None, 256, 256, 12)         48        ['depthwise_conv2d_30[0][0]']
#  wiseConv2D)
#
#  conv2d_66 (Conv2D)          (None, 256, 256, 12)         444       ['conv2d_65[0][0]']
#
#  batch_normalization_61 (Ba  (None, 256, 256, 12)         48        ['depthwise_conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_62 (Ba  (None, 256, 256, 12)         48        ['conv2d_66[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_65 (TFOpLambda)  (None, 256, 256, 12)         0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  tf.nn.relu_66 (TFOpLambda)  (None, 256, 256, 12)         0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  concatenate_21 (Concatenat  (None, 256, 256, 24)         0         ['tf.nn.relu_65[0][0]',
#  e)                                                                  'tf.nn.relu_66[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 256, 256, 12)         300       ['concatenate_21[0][0]']
#
#  batch_normalization_63 (Ba  (None, 256, 256, 12)         48        ['conv2d_67[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_67 (TFOpLambda)  (None, 256, 256, 12)         0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  add_23 (Add)                (None, 256, 256, 12)         0         ['add_22[0][0]',
#                                                                      'tf.nn.relu_67[0][0]']
#
#  add_24 (Add)                (None, 256, 256, 12)         0         ['tf.nn.relu_60[0][0]',
#                                                                      'add_23[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 256, 256, 1)          13        ['add_24[0][0]']
#
# ==================================================================================================
# Total params: 648457 (2.47 MB)
# Trainable params: 643929 (2.46 MB)
# Non-trainable params: 4528 (17.69 KB)
# __________________________________________________________________________________________________

# %%
opt = keras.optimizers.Adam(learning_rate=0.01)
proposed_model.compile(optimizer=opt,
              loss= dice_coef_loss,
              metrics=[jaccard_coef,dice_coef,'accuracy'])

# %%
lrd = ReduceLROnPlateau(monitor = 'val_loss',
                         patience =10,
                         verbose = 1,
                         factor = 0.1,
                         min_lr = 0.00001)

mcp = ModelCheckpoint(filepath=r"model_hpo.h5",
    save_weights_only=True,
    monitor='val_jaccard_coef',
    mode='auto',
    verbose=0,
    save_best_only=False)

# %%
EPOCH = 100

# %%
now = time.time()
history1 = proposed_model.fit(tr_image, tr_mask, batch_size=16, epochs=EPOCH, validation_data=(vl_image, vl_mask), shuffle=True, callbacks = [lrd , mcp])
end = time.time()
print('time: ', end - now)
# Out:
# Epoch 1/100
# 150/150 [==============================] - 107s 264ms/step - loss: 0.1869 - jaccard_coef: 0.6928 - dice_coef: 0.8132 - accuracy: 0.9212 - val_loss: 0.7751 - val_jaccard_coef: 0.1274 - val_dice_coef: 0.2256 - val_accuracy: 0.7374 - lr: 0.0100
# Epoch 2/100
# 150/150 [==============================] - 34s 229ms/step - loss: 0.1338 - jaccard_coef: 0.7648 - dice_coef: 0.8662 - accuracy: 0.9471 - val_loss: 0.9930 - val_jaccard_coef: 0.0035 - val_dice_coef: 0.0069 - val_accuracy: 0.8067 - lr: 0.0100
# Epoch 3/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.1271 - jaccard_coef: 0.7752 - dice_coef: 0.8729 - accuracy: 0.9498 - val_loss: 0.3433 - val_jaccard_coef: 0.4916 - val_dice_coef: 0.6569 - val_accuracy: 0.8237 - lr: 0.0100
# Epoch 4/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.1142 - jaccard_coef: 0.7957 - dice_coef: 0.8858 - accuracy: 0.9548 - val_loss: 0.1759 - val_jaccard_coef: 0.7014 - val_dice_coef: 0.8242 - val_accuracy: 0.9387 - lr: 0.0100
# Epoch 5/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.1141 - jaccard_coef: 0.7958 - dice_coef: 0.8859 - accuracy: 0.9548 - val_loss: 0.2429 - val_jaccard_coef: 0.6112 - val_dice_coef: 0.7576 - val_accuracy: 0.8944 - lr: 0.0100
# Epoch 6/100
# 150/150 [==============================] - 34s 229ms/step - loss: 0.1081 - jaccard_coef: 0.8055 - dice_coef: 0.8919 - accuracy: 0.9571 - val_loss: 0.3225 - val_jaccard_coef: 0.5134 - val_dice_coef: 0.6779 - val_accuracy: 0.8313 - lr: 0.0100
# Epoch 7/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.1040 - jaccard_coef: 0.8122 - dice_coef: 0.8960 - accuracy: 0.9588 - val_loss: 0.2367 - val_jaccard_coef: 0.6181 - val_dice_coef: 0.7631 - val_accuracy: 0.9230 - lr: 0.0100
# Epoch 8/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.1031 - jaccard_coef: 0.8137 - dice_coef: 0.8969 - accuracy: 0.9592 - val_loss: 0.2079 - val_jaccard_coef: 0.6582 - val_dice_coef: 0.7929 - val_accuracy: 0.9091 - lr: 0.0100
# Epoch 9/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0979 - jaccard_coef: 0.8222 - dice_coef: 0.9021 - accuracy: 0.9613 - val_loss: 0.2510 - val_jaccard_coef: 0.6002 - val_dice_coef: 0.7495 - val_accuracy: 0.8927 - lr: 0.0100
# Epoch 10/100
# 150/150 [==============================] - 34s 229ms/step - loss: 0.0962 - jaccard_coef: 0.8248 - dice_coef: 0.9038 - accuracy: 0.9619 - val_loss: 0.2486 - val_jaccard_coef: 0.6029 - val_dice_coef: 0.7517 - val_accuracy: 0.8824 - lr: 0.0100
# Epoch 11/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0891 - jaccard_coef: 0.8367 - dice_coef: 0.9109 - accuracy: 0.9646 - val_loss: 0.0944 - val_jaccard_coef: 0.8283 - val_dice_coef: 0.9058 - val_accuracy: 0.9640 - lr: 0.0100
# Epoch 12/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0901 - jaccard_coef: 0.8351 - dice_coef: 0.9099 - accuracy: 0.9643 - val_loss: 0.1498 - val_jaccard_coef: 0.7423 - val_dice_coef: 0.8508 - val_accuracy: 0.9384 - lr: 0.0100
# Epoch 13/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0905 - jaccard_coef: 0.8344 - dice_coef: 0.9095 - accuracy: 0.9640 - val_loss: 0.4089 - val_jaccard_coef: 0.4231 - val_dice_coef: 0.5916 - val_accuracy: 0.8659 - lr: 0.0100
# Epoch 14/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0918 - jaccard_coef: 0.8321 - dice_coef: 0.9082 - accuracy: 0.9636 - val_loss: 0.1453 - val_jaccard_coef: 0.7477 - val_dice_coef: 0.8552 - val_accuracy: 0.9446 - lr: 0.0100
# Epoch 15/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0865 - jaccard_coef: 0.8412 - dice_coef: 0.9135 - accuracy: 0.9658 - val_loss: 0.1161 - val_jaccard_coef: 0.7922 - val_dice_coef: 0.8838 - val_accuracy: 0.9584 - lr: 0.0100
# Epoch 16/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0852 - jaccard_coef: 0.8434 - dice_coef: 0.9149 - accuracy: 0.9661 - val_loss: 0.1947 - val_jaccard_coef: 0.6749 - val_dice_coef: 0.8053 - val_accuracy: 0.9110 - lr: 0.0100
# Epoch 17/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0820 - jaccard_coef: 0.8487 - dice_coef: 0.9180 - accuracy: 0.9675 - val_loss: 0.0813 - val_jaccard_coef: 0.8499 - val_dice_coef: 0.9188 - val_accuracy: 0.9688 - lr: 0.0100
# Epoch 18/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0803 - jaccard_coef: 0.8515 - dice_coef: 0.9197 - accuracy: 0.9681 - val_loss: 0.2002 - val_jaccard_coef: 0.6673 - val_dice_coef: 0.7997 - val_accuracy: 0.9075 - lr: 0.0100
# Epoch 19/100
# 150/150 [==============================] - 34s 229ms/step - loss: 0.0802 - jaccard_coef: 0.8517 - dice_coef: 0.9198 - accuracy: 0.9683 - val_loss: 0.0856 - val_jaccard_coef: 0.8427 - val_dice_coef: 0.9145 - val_accuracy: 0.9676 - lr: 0.0100
# Epoch 20/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0795 - jaccard_coef: 0.8530 - dice_coef: 0.9205 - accuracy: 0.9684 - val_loss: 0.2095 - val_jaccard_coef: 0.6549 - val_dice_coef: 0.7909 - val_accuracy: 0.9085 - lr: 0.0100
# Epoch 21/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0773 - jaccard_coef: 0.8567 - dice_coef: 0.9227 - accuracy: 0.9694 - val_loss: 0.0951 - val_jaccard_coef: 0.8267 - val_dice_coef: 0.9049 - val_accuracy: 0.9637 - lr: 0.0100
# Epoch 22/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0825 - jaccard_coef: 0.8478 - dice_coef: 0.9175 - accuracy: 0.9672 - val_loss: 0.0912 - val_jaccard_coef: 0.8334 - val_dice_coef: 0.9090 - val_accuracy: 0.9655 - lr: 0.0100
# Epoch 23/100
# 150/150 [==============================] - 33s 222ms/step - loss: 0.0772 - jaccard_coef: 0.8569 - dice_coef: 0.9228 - accuracy: 0.9694 - val_loss: 0.0790 - val_jaccard_coef: 0.8539 - val_dice_coef: 0.9211 - val_accuracy: 0.9703 - lr: 0.0100
# Epoch 24/100
# 150/150 [==============================] - 35s 230ms/step - loss: 0.0742 - jaccard_coef: 0.8619 - dice_coef: 0.9258 - accuracy: 0.9705 - val_loss: 0.0843 - val_jaccard_coef: 0.8449 - val_dice_coef: 0.9158 - val_accuracy: 0.9679 - lr: 0.0100
# Epoch 25/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0788 - jaccard_coef: 0.8542 - dice_coef: 0.9212 - accuracy: 0.9687 - val_loss: 0.1318 - val_jaccard_coef: 0.7678 - val_dice_coef: 0.8683 - val_accuracy: 0.9458 - lr: 0.0100
# Epoch 26/100
# 150/150 [==============================] - 33s 219ms/step - loss: 0.0752 - jaccard_coef: 0.8604 - dice_coef: 0.9248 - accuracy: 0.9703 - val_loss: 0.1131 - val_jaccard_coef: 0.7970 - val_dice_coef: 0.8869 - val_accuracy: 0.9538 - lr: 0.0100
# Epoch 27/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0738 - jaccard_coef: 0.8628 - dice_coef: 0.9262 - accuracy: 0.9707 - val_loss: 0.0912 - val_jaccard_coef: 0.8331 - val_dice_coef: 0.9089 - val_accuracy: 0.9650 - lr: 0.0100
# Epoch 28/100
# 150/150 [==============================] - 34s 229ms/step - loss: 0.0755 - jaccard_coef: 0.8597 - dice_coef: 0.9244 - accuracy: 0.9700 - val_loss: 0.1309 - val_jaccard_coef: 0.7690 - val_dice_coef: 0.8692 - val_accuracy: 0.9526 - lr: 0.0100
# Epoch 29/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0766 - jaccard_coef: 0.8580 - dice_coef: 0.9234 - accuracy: 0.9697 - val_loss: 0.4541 - val_jaccard_coef: 0.3769 - val_dice_coef: 0.5461 - val_accuracy: 0.6872 - lr: 0.0100
# Epoch 30/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0805 - jaccard_coef: 0.8513 - dice_coef: 0.9195 - accuracy: 0.9680 - val_loss: 0.1078 - val_jaccard_coef: 0.8057 - val_dice_coef: 0.8922 - val_accuracy: 0.9593 - lr: 0.0100
# Epoch 31/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0771 - jaccard_coef: 0.8570 - dice_coef: 0.9229 - accuracy: 0.9694 - val_loss: 0.1524 - val_jaccard_coef: 0.7361 - val_dice_coef: 0.8476 - val_accuracy: 0.9359 - lr: 0.0100
# Epoch 32/100
# 150/150 [==============================] - 34s 230ms/step - loss: 0.0809 - jaccard_coef: 0.8508 - dice_coef: 0.9191 - accuracy: 0.9680 - val_loss: 0.0891 - val_jaccard_coef: 0.8367 - val_dice_coef: 0.9109 - val_accuracy: 0.9651 - lr: 0.0100
# Epoch 33/100
# 150/150 [==============================] - ETA: 0s - loss: 0.0738 - jaccard_coef: 0.8627 - dice_coef: 0.9262 - accuracy: 0.9706
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0738 - jaccard_coef: 0.8627 - dice_coef: 0.9262 - accuracy: 0.9706 - val_loss: 0.0871 - val_jaccard_coef: 0.8401 - val_dice_coef: 0.9129 - val_accuracy: 0.9662 - lr: 0.0100
# Epoch 34/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0689 - jaccard_coef: 0.8713 - dice_coef: 0.9311 - accuracy: 0.9726 - val_loss: 0.0674 - val_jaccard_coef: 0.8741 - val_dice_coef: 0.9327 - val_accuracy: 0.9743 - lr: 1.0000e-03
# Epoch 35/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0675 - jaccard_coef: 0.8739 - dice_coef: 0.9325 - accuracy: 0.9734 - val_loss: 0.0660 - val_jaccard_coef: 0.8765 - val_dice_coef: 0.9341 - val_accuracy: 0.9749 - lr: 1.0000e-03
# Epoch 36/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0656 - jaccard_coef: 0.8770 - dice_coef: 0.9344 - accuracy: 0.9739 - val_loss: 0.0655 - val_jaccard_coef: 0.8774 - val_dice_coef: 0.9346 - val_accuracy: 0.9751 - lr: 1.0000e-03
# Epoch 37/100
# 150/150 [==============================] - 34s 230ms/step - loss: 0.0655 - jaccard_coef: 0.8773 - dice_coef: 0.9345 - accuracy: 0.9740 - val_loss: 0.0651 - val_jaccard_coef: 0.8779 - val_dice_coef: 0.9349 - val_accuracy: 0.9753 - lr: 1.0000e-03
# Epoch 38/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0646 - jaccard_coef: 0.8787 - dice_coef: 0.9354 - accuracy: 0.9743 - val_loss: 0.0653 - val_jaccard_coef: 0.8775 - val_dice_coef: 0.9347 - val_accuracy: 0.9751 - lr: 1.0000e-03
# Epoch 39/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0642 - jaccard_coef: 0.8794 - dice_coef: 0.9358 - accuracy: 0.9744 - val_loss: 0.0656 - val_jaccard_coef: 0.8770 - val_dice_coef: 0.9344 - val_accuracy: 0.9749 - lr: 1.0000e-03
# Epoch 40/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0634 - jaccard_coef: 0.8810 - dice_coef: 0.9366 - accuracy: 0.9748 - val_loss: 0.0654 - val_jaccard_coef: 0.8774 - val_dice_coef: 0.9346 - val_accuracy: 0.9751 - lr: 1.0000e-03
# Epoch 41/100
# 150/150 [==============================] - 35s 231ms/step - loss: 0.0638 - jaccard_coef: 0.8802 - dice_coef: 0.9362 - accuracy: 0.9747 - val_loss: 0.0650 - val_jaccard_coef: 0.8780 - val_dice_coef: 0.9349 - val_accuracy: 0.9752 - lr: 1.0000e-03
# Epoch 42/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0631 - jaccard_coef: 0.8815 - dice_coef: 0.9369 - accuracy: 0.9749 - val_loss: 0.0647 - val_jaccard_coef: 0.8788 - val_dice_coef: 0.9354 - val_accuracy: 0.9755 - lr: 1.0000e-03
# Epoch 43/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0630 - jaccard_coef: 0.8816 - dice_coef: 0.9370 - accuracy: 0.9750 - val_loss: 0.0641 - val_jaccard_coef: 0.8797 - val_dice_coef: 0.9359 - val_accuracy: 0.9757 - lr: 1.0000e-03
# Epoch 44/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0629 - jaccard_coef: 0.8818 - dice_coef: 0.9371 - accuracy: 0.9751 - val_loss: 0.0643 - val_jaccard_coef: 0.8793 - val_dice_coef: 0.9357 - val_accuracy: 0.9753 - lr: 1.0000e-03
# Epoch 45/100
# 150/150 [==============================] - 33s 222ms/step - loss: 0.0625 - jaccard_coef: 0.8824 - dice_coef: 0.9375 - accuracy: 0.9751 - val_loss: 0.0649 - val_jaccard_coef: 0.8782 - val_dice_coef: 0.9351 - val_accuracy: 0.9752 - lr: 1.0000e-03
# Epoch 46/100
# 150/150 [==============================] - 33s 222ms/step - loss: 0.0626 - jaccard_coef: 0.8824 - dice_coef: 0.9374 - accuracy: 0.9752 - val_loss: 0.0636 - val_jaccard_coef: 0.8805 - val_dice_coef: 0.9364 - val_accuracy: 0.9756 - lr: 1.0000e-03
# Epoch 47/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0620 - jaccard_coef: 0.8834 - dice_coef: 0.9380 - accuracy: 0.9753 - val_loss: 0.0645 - val_jaccard_coef: 0.8789 - val_dice_coef: 0.9355 - val_accuracy: 0.9756 - lr: 1.0000e-03
# Epoch 48/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0619 - jaccard_coef: 0.8836 - dice_coef: 0.9381 - accuracy: 0.9755 - val_loss: 0.0642 - val_jaccard_coef: 0.8795 - val_dice_coef: 0.9358 - val_accuracy: 0.9754 - lr: 1.0000e-03
# Epoch 49/100
# 150/150 [==============================] - 33s 222ms/step - loss: 0.0619 - jaccard_coef: 0.8835 - dice_coef: 0.9381 - accuracy: 0.9754 - val_loss: 0.0655 - val_jaccard_coef: 0.8771 - val_dice_coef: 0.9344 - val_accuracy: 0.9748 - lr: 1.0000e-03
# Epoch 50/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0616 - jaccard_coef: 0.8841 - dice_coef: 0.9384 - accuracy: 0.9756 - val_loss: 0.0635 - val_jaccard_coef: 0.8807 - val_dice_coef: 0.9365 - val_accuracy: 0.9757 - lr: 1.0000e-03
# Epoch 51/100
# 150/150 [==============================] - 34s 230ms/step - loss: 0.0613 - jaccard_coef: 0.8847 - dice_coef: 0.9387 - accuracy: 0.9757 - val_loss: 0.0637 - val_jaccard_coef: 0.8802 - val_dice_coef: 0.9362 - val_accuracy: 0.9757 - lr: 1.0000e-03
# Epoch 52/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0610 - jaccard_coef: 0.8851 - dice_coef: 0.9390 - accuracy: 0.9758 - val_loss: 0.0632 - val_jaccard_coef: 0.8813 - val_dice_coef: 0.9368 - val_accuracy: 0.9761 - lr: 1.0000e-03
# Epoch 53/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0607 - jaccard_coef: 0.8857 - dice_coef: 0.9393 - accuracy: 0.9759 - val_loss: 0.0631 - val_jaccard_coef: 0.8814 - val_dice_coef: 0.9369 - val_accuracy: 0.9759 - lr: 1.0000e-03
# Epoch 54/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0606 - jaccard_coef: 0.8858 - dice_coef: 0.9394 - accuracy: 0.9759 - val_loss: 0.0629 - val_jaccard_coef: 0.8817 - val_dice_coef: 0.9370 - val_accuracy: 0.9759 - lr: 1.0000e-03
# Epoch 55/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0605 - jaccard_coef: 0.8860 - dice_coef: 0.9395 - accuracy: 0.9760 - val_loss: 0.0626 - val_jaccard_coef: 0.8822 - val_dice_coef: 0.9374 - val_accuracy: 0.9760 - lr: 1.0000e-03
# Epoch 56/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0604 - jaccard_coef: 0.8862 - dice_coef: 0.9396 - accuracy: 0.9760 - val_loss: 0.0665 - val_jaccard_coef: 0.8754 - val_dice_coef: 0.9335 - val_accuracy: 0.9743 - lr: 1.0000e-03
# Epoch 57/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0600 - jaccard_coef: 0.8870 - dice_coef: 0.9400 - accuracy: 0.9762 - val_loss: 0.0654 - val_jaccard_coef: 0.8773 - val_dice_coef: 0.9346 - val_accuracy: 0.9749 - lr: 1.0000e-03
# Epoch 58/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0598 - jaccard_coef: 0.8873 - dice_coef: 0.9402 - accuracy: 0.9763 - val_loss: 0.0626 - val_jaccard_coef: 0.8823 - val_dice_coef: 0.9374 - val_accuracy: 0.9761 - lr: 1.0000e-03
# Epoch 59/100
# 150/150 [==============================] - 33s 219ms/step - loss: 0.0598 - jaccard_coef: 0.8873 - dice_coef: 0.9402 - accuracy: 0.9762 - val_loss: 0.0637 - val_jaccard_coef: 0.8803 - val_dice_coef: 0.9363 - val_accuracy: 0.9757 - lr: 1.0000e-03
# Epoch 60/100
# 150/150 [==============================] - 33s 222ms/step - loss: 0.0598 - jaccard_coef: 0.8872 - dice_coef: 0.9402 - accuracy: 0.9763 - val_loss: 0.0625 - val_jaccard_coef: 0.8824 - val_dice_coef: 0.9374 - val_accuracy: 0.9762 - lr: 1.0000e-03
# Epoch 61/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0595 - jaccard_coef: 0.8878 - dice_coef: 0.9405 - accuracy: 0.9764 - val_loss: 0.0634 - val_jaccard_coef: 0.8808 - val_dice_coef: 0.9366 - val_accuracy: 0.9760 - lr: 1.0000e-03
# Epoch 62/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0595 - jaccard_coef: 0.8879 - dice_coef: 0.9405 - accuracy: 0.9765 - val_loss: 0.0628 - val_jaccard_coef: 0.8820 - val_dice_coef: 0.9372 - val_accuracy: 0.9760 - lr: 1.0000e-03
# Epoch 63/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0588 - jaccard_coef: 0.8891 - dice_coef: 0.9412 - accuracy: 0.9767 - val_loss: 0.0630 - val_jaccard_coef: 0.8817 - val_dice_coef: 0.9370 - val_accuracy: 0.9760 - lr: 1.0000e-03
# Epoch 64/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0590 - jaccard_coef: 0.8887 - dice_coef: 0.9410 - accuracy: 0.9766 - val_loss: 0.0630 - val_jaccard_coef: 0.8816 - val_dice_coef: 0.9370 - val_accuracy: 0.9760 - lr: 1.0000e-03
# Epoch 65/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0593 - jaccard_coef: 0.8881 - dice_coef: 0.9407 - accuracy: 0.9765 - val_loss: 0.0622 - val_jaccard_coef: 0.8830 - val_dice_coef: 0.9378 - val_accuracy: 0.9764 - lr: 1.0000e-03
# Epoch 66/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0590 - jaccard_coef: 0.8886 - dice_coef: 0.9410 - accuracy: 0.9766 - val_loss: 0.0627 - val_jaccard_coef: 0.8821 - val_dice_coef: 0.9373 - val_accuracy: 0.9760 - lr: 1.0000e-03
# Epoch 67/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0597 - jaccard_coef: 0.8875 - dice_coef: 0.9403 - accuracy: 0.9764 - val_loss: 0.0648 - val_jaccard_coef: 0.8783 - val_dice_coef: 0.9351 - val_accuracy: 0.9753 - lr: 1.0000e-03
# Epoch 68/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0584 - jaccard_coef: 0.8897 - dice_coef: 0.9416 - accuracy: 0.9768 - val_loss: 0.0623 - val_jaccard_coef: 0.8828 - val_dice_coef: 0.9377 - val_accuracy: 0.9762 - lr: 1.0000e-03
# Epoch 69/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0581 - jaccard_coef: 0.8903 - dice_coef: 0.9419 - accuracy: 0.9769 - val_loss: 0.0635 - val_jaccard_coef: 0.8808 - val_dice_coef: 0.9365 - val_accuracy: 0.9758 - lr: 1.0000e-03
# Epoch 70/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0588 - jaccard_coef: 0.8890 - dice_coef: 0.9412 - accuracy: 0.9766 - val_loss: 0.0624 - val_jaccard_coef: 0.8827 - val_dice_coef: 0.9376 - val_accuracy: 0.9762 - lr: 1.0000e-03
# Epoch 71/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0582 - jaccard_coef: 0.8901 - dice_coef: 0.9418 - accuracy: 0.9769 - val_loss: 0.0622 - val_jaccard_coef: 0.8831 - val_dice_coef: 0.9378 - val_accuracy: 0.9762 - lr: 1.0000e-03
# Epoch 72/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0578 - jaccard_coef: 0.8908 - dice_coef: 0.9422 - accuracy: 0.9770 - val_loss: 0.0626 - val_jaccard_coef: 0.8823 - val_dice_coef: 0.9374 - val_accuracy: 0.9761 - lr: 1.0000e-03
# Epoch 73/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0577 - jaccard_coef: 0.8909 - dice_coef: 0.9422 - accuracy: 0.9771 - val_loss: 0.0632 - val_jaccard_coef: 0.8812 - val_dice_coef: 0.9367 - val_accuracy: 0.9759 - lr: 1.0000e-03
# Epoch 74/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0579 - jaccard_coef: 0.8907 - dice_coef: 0.9421 - accuracy: 0.9770 - val_loss: 0.0657 - val_jaccard_coef: 0.8769 - val_dice_coef: 0.9343 - val_accuracy: 0.9752 - lr: 1.0000e-03
# Epoch 75/100
# 150/150 [==============================] - ETA: 0s - loss: 0.0580 - jaccard_coef: 0.8905 - dice_coef: 0.9420 - accuracy: 0.9770
# Epoch 75: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 150/150 [==============================] - 35s 232ms/step - loss: 0.0580 - jaccard_coef: 0.8905 - dice_coef: 0.9420 - accuracy: 0.9770 - val_loss: 0.0647 - val_jaccard_coef: 0.8787 - val_dice_coef: 0.9353 - val_accuracy: 0.9753 - lr: 1.0000e-03
# Epoch 76/100
# 150/150 [==============================] - 33s 222ms/step - loss: 0.0572 - jaccard_coef: 0.8918 - dice_coef: 0.9428 - accuracy: 0.9772 - val_loss: 0.0628 - val_jaccard_coef: 0.8819 - val_dice_coef: 0.9372 - val_accuracy: 0.9761 - lr: 1.0000e-04
# Epoch 77/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0572 - jaccard_coef: 0.8920 - dice_coef: 0.9428 - accuracy: 0.9773 - val_loss: 0.0623 - val_jaccard_coef: 0.8828 - val_dice_coef: 0.9377 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 78/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0569 - jaccard_coef: 0.8925 - dice_coef: 0.9431 - accuracy: 0.9774 - val_loss: 0.0620 - val_jaccard_coef: 0.8833 - val_dice_coef: 0.9380 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 79/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0566 - jaccard_coef: 0.8930 - dice_coef: 0.9434 - accuracy: 0.9775 - val_loss: 0.0621 - val_jaccard_coef: 0.8832 - val_dice_coef: 0.9379 - val_accuracy: 0.9763 - lr: 1.0000e-04
# Epoch 80/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0570 - jaccard_coef: 0.8922 - dice_coef: 0.9430 - accuracy: 0.9774 - val_loss: 0.0620 - val_jaccard_coef: 0.8834 - val_dice_coef: 0.9380 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 81/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0570 - jaccard_coef: 0.8923 - dice_coef: 0.9430 - accuracy: 0.9774 - val_loss: 0.0621 - val_jaccard_coef: 0.8833 - val_dice_coef: 0.9379 - val_accuracy: 0.9763 - lr: 1.0000e-04
# Epoch 82/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0565 - jaccard_coef: 0.8932 - dice_coef: 0.9435 - accuracy: 0.9775 - val_loss: 0.0622 - val_jaccard_coef: 0.8830 - val_dice_coef: 0.9378 - val_accuracy: 0.9763 - lr: 1.0000e-04
# Epoch 83/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0569 - jaccard_coef: 0.8924 - dice_coef: 0.9431 - accuracy: 0.9775 - val_loss: 0.0619 - val_jaccard_coef: 0.8835 - val_dice_coef: 0.9381 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 84/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0568 - jaccard_coef: 0.8926 - dice_coef: 0.9432 - accuracy: 0.9774 - val_loss: 0.0620 - val_jaccard_coef: 0.8834 - val_dice_coef: 0.9380 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 85/100
# 150/150 [==============================] - 34s 230ms/step - loss: 0.0564 - jaccard_coef: 0.8933 - dice_coef: 0.9436 - accuracy: 0.9775 - val_loss: 0.0620 - val_jaccard_coef: 0.8834 - val_dice_coef: 0.9380 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 86/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0566 - jaccard_coef: 0.8930 - dice_coef: 0.9434 - accuracy: 0.9775 - val_loss: 0.0619 - val_jaccard_coef: 0.8836 - val_dice_coef: 0.9381 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 87/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0566 - jaccard_coef: 0.8930 - dice_coef: 0.9434 - accuracy: 0.9776 - val_loss: 0.0619 - val_jaccard_coef: 0.8836 - val_dice_coef: 0.9381 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 88/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0565 - jaccard_coef: 0.8932 - dice_coef: 0.9435 - accuracy: 0.9775 - val_loss: 0.0619 - val_jaccard_coef: 0.8836 - val_dice_coef: 0.9381 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 89/100
# 150/150 [==============================] - 35s 230ms/step - loss: 0.0565 - jaccard_coef: 0.8932 - dice_coef: 0.9435 - accuracy: 0.9776 - val_loss: 0.0619 - val_jaccard_coef: 0.8836 - val_dice_coef: 0.9381 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 90/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0564 - jaccard_coef: 0.8934 - dice_coef: 0.9437 - accuracy: 0.9776 - val_loss: 0.0618 - val_jaccard_coef: 0.8837 - val_dice_coef: 0.9382 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 91/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0567 - jaccard_coef: 0.8927 - dice_coef: 0.9433 - accuracy: 0.9775 - val_loss: 0.0620 - val_jaccard_coef: 0.8834 - val_dice_coef: 0.9380 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 92/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0565 - jaccard_coef: 0.8932 - dice_coef: 0.9435 - accuracy: 0.9776 - val_loss: 0.0619 - val_jaccard_coef: 0.8836 - val_dice_coef: 0.9381 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 93/100
# 150/150 [==============================] - 33s 222ms/step - loss: 0.0568 - jaccard_coef: 0.8928 - dice_coef: 0.9432 - accuracy: 0.9775 - val_loss: 0.0620 - val_jaccard_coef: 0.8835 - val_dice_coef: 0.9381 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 94/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0564 - jaccard_coef: 0.8932 - dice_coef: 0.9436 - accuracy: 0.9775 - val_loss: 0.0620 - val_jaccard_coef: 0.8835 - val_dice_coef: 0.9380 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 95/100
# 150/150 [==============================] - 33s 220ms/step - loss: 0.0564 - jaccard_coef: 0.8933 - dice_coef: 0.9436 - accuracy: 0.9776 - val_loss: 0.0617 - val_jaccard_coef: 0.8839 - val_dice_coef: 0.9383 - val_accuracy: 0.9765 - lr: 1.0000e-04
# Epoch 96/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0566 - jaccard_coef: 0.8930 - dice_coef: 0.9434 - accuracy: 0.9776 - val_loss: 0.0618 - val_jaccard_coef: 0.8837 - val_dice_coef: 0.9382 - val_accuracy: 0.9765 - lr: 1.0000e-04
# Epoch 97/100
# 150/150 [==============================] - 33s 222ms/step - loss: 0.0565 - jaccard_coef: 0.8932 - dice_coef: 0.9435 - accuracy: 0.9775 - val_loss: 0.0617 - val_jaccard_coef: 0.8839 - val_dice_coef: 0.9383 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 98/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0568 - jaccard_coef: 0.8926 - dice_coef: 0.9432 - accuracy: 0.9775 - val_loss: 0.0618 - val_jaccard_coef: 0.8837 - val_dice_coef: 0.9382 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 99/100
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0564 - jaccard_coef: 0.8934 - dice_coef: 0.9436 - accuracy: 0.9776 - val_loss: 0.0620 - val_jaccard_coef: 0.8835 - val_dice_coef: 0.9380 - val_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 100/100
# 150/150 [==============================] - ETA: 0s - loss: 0.0563 - jaccard_coef: 0.8935 - dice_coef: 0.9437 - accuracy: 0.9777
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1e-05.
# 150/150 [==============================] - 33s 221ms/step - loss: 0.0563 - jaccard_coef: 0.8935 - dice_coef: 0.9437 - accuracy: 0.9777 - val_loss: 0.0618 - val_jaccard_coef: 0.8837 - val_dice_coef: 0.9382 - val_accuracy: 0.9764 - lr: 1.0000e-04
# time:  3419.7180228233337

# %%
proposed_model.save('WHU_proposed_model.h5')
import pickle
with open('WHU_proposed_model.pickle' , 'wb') as file:
  pickle.dump(history1.history,file)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
proposed_model = tf.keras.models.load_model('WHU_proposed_model.h5', custom_objects = {'dice_coef': dice_coef,
            'jaccard_coef_loss': jaccard_coef_loss,
            'jaccard_coef':jaccard_coef,
            'dice_coef_loss': dice_coef_loss})

# %%
pred_val = proposed_model.predict(vl_image)
pred_test = proposed_model.predict(ts_image)

true_test = (ts_mask>0.5).flatten() #orjinal test maskesi
true_val  = (vl_mask>0.5).flatten() #orjinal validation maskesi
pred_test = (pred_test>0.5).flatten()
pred_val = (pred_val>0.5).flatten()

#test miou  #keras in MeanIOU fonksiyonu bu camvid veri seti için
#build ve background nesnelerinin ortalamasini alir. build = 1 ve Background = 0 dir.
miou = tf.keras.metrics.MeanIoU(num_classes= 2)
miou.update_state(true_test, pred_test)
print('Test data MIOU :',miou.result().numpy())

#val miou
miou = tf.keras.metrics.MeanIoU(num_classes= 2)
miou.update_state(true_val, pred_val)
print('Validation data MIOU :',miou.result().numpy())
# Out:
# 10/10 [==============================] - 5s 110ms/step
# 10/10 [==============================] - 1s 116ms/step
# Test data MIOU : 0.92069864
# Validation data MIOU : 0.9281266

# %%
import pickle
import matplotlib.pyplot as plt

# %%
proposed_deeplab = pickle.load(open('WHU_proposed_model.pickle', "rb"))

# %%
print('\n',proposed_deeplab.keys())
# Out:
#  dict_keys(['loss', 'jaccard_coef', 'dice_coef', 'accuracy', 'val_loss', 'val_jaccard_coef', 'val_dice_coef', 'val_accuracy', 'lr'])

# %%
epochs = range(EPOCH)

# %%
#acc
fig,(ax1) = plt.subplots(1,1)
ax1.plot(epochs, proposed_deeplab['accuracy'], 'b', label='Training Set')
ax1.plot(epochs, proposed_deeplab['val_accuracy'], 'r', label='Validation Set')
ax1.legend(loc='lower right', shadow=True)
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend()

# %%
#loss
fig,(ax1) = plt.subplots(1,1)
ax1.plot(epochs, proposed_deeplab['loss'], 'b', label='Training Set')
ax1.plot(epochs, proposed_deeplab['val_loss'], 'r', label='Validation Set')
ax1.legend(loc='lower right', shadow=True)
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()

# %%
#dice
fig,(ax1) = plt.subplots(1,1)
ax1.plot(epochs, proposed_deeplab['dice_coef'], 'b', label='Training Set')
ax1.plot(epochs, proposed_deeplab['val_dice_coef'], 'r', label='Validation Set')
ax1.legend(loc='lower right', shadow=True)
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Dice Coefficient')
ax1.legend()

# %%
#jaccard
fig,(ax1) = plt.subplots(1,1)
ax1.plot(epochs, proposed_deeplab['jaccard_coef'], 'b', label='Training Set')
ax1.plot(epochs, proposed_deeplab['val_jaccard_coef'], 'r', label='Validation Set')
ax1.legend(loc='lower right', shadow=True)
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Jaccard Coefficient')
ax1.legend()

# %%
proposed_model = tf.keras.models.load_model('WHU_proposed_model.h5', custom_objects = {'dice_coef': dice_coef,
            'jaccard_coef_loss': jaccard_coef_loss,
            'jaccard_coef':jaccard_coef,
            'dice_coef_loss': dice_coef_loss})

# %%
deeplab_val = proposed_model.predict(vl_image)
deeplab_ts = proposed_model.predict(ts_image)
# Out:
# 10/10 [==============================] - 4s 116ms/step
# 10/10 [==============================] - 1s 116ms/step

# %%
deeplab_val_argmax = (deeplab_val > 0.5).astype(np.uint8)
deeplab_ts_argmax = (deeplab_ts > 0.5).astype(np.uint8)

# %%
def vis_validation(num):
    fig,(ax1,ax2,ax3) = plt.subplots(1,3)
    fig.set_figheight(7)
    fig.set_figwidth(14)

    ax1.axis('off')
    ax1.imshow(ts_image[num])
    ax1.set_title('Original Image')

    ax2.axis('off')
    ax2.imshow(np.squeeze(ts_mask[num]), cmap='gray') #256x256x1 olan boyutu 256x256 yapmaliyiz onuda np.squeeze ile yapariz.
    ax2.set_title('Original Mask')

    ax3.axis('off')
    ax3.imshow(np.squeeze(deeplab_ts_argmax[num]), cmap='gray') #256x256x1 olan boyutu 256x256 yapmaliyiz onuda np.squeeze ile yapariz.
    ax3.set_title('Proposed Method')

# %%
vis_validation(23)
